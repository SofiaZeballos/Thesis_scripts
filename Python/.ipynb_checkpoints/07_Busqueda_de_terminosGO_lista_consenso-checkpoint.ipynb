# %%
# ----- Packages -----
from goatools.anno.gaf_reader import GafReader

# %%
ogaf = GafReader("wb.gaf")
# Out:
# **WARNING: NO VERSION LINE FOUND IN GAF FILE. USING:
# !gaf-version: 2.2
# ERROR:root:Failed to validate header as GAF v2.2:
# []
# HMS:0:00:01.487420 133,336 annotations READ: wb.gaf

# %%
ns2assc = ogaf.get_ns2assc()

# %%
import pandas as pd 

interseccion_df = pd.read_csv(r"C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Analisis_interseccion\descripción_genes_interseccion.csv",
                             sep=',')

interseccion = list(interseccion_df['WBID'])
interseccion_names = list(interseccion_df['Public_Name'])

# %%
# Creamos un nuevo diccionario para almacenar los valores
nuevo_diccionario = {}

# Iteramos sobre cada clave en ns2assc
for clave, dic_genes in ns2assc.items():
    # Iteramos sobre cada gen en el diccionario de genes
    for gen, valor in dic_genes.items():
        # Verificamos si el gen está en la lista de genes
        if gen in interseccion:
            # Sumamos el valor al valor existente en nuevo_diccionario[gen], si el gen ya está en el diccionario
            if gen in nuevo_diccionario:
                nuevo_diccionario[gen] += list(valor)
            else:
                # Si el gen no está en el diccionario, almacenamos el valor como está
                nuevo_diccionario[gen] = list(valor)

# %%
nuevo_diccionario['WBGene00019007']
# Out:
# ['GO:0005750', 'GO:0005743', 'GO:0005739', 'GO:0006122']

# %% [markdown]
# Agregarle los ancestros

# %%
import os
from goatools.obo_parser import GODag

# Load a small test GO DAG and all the optional relationships,
# like 'regulates' and 'part_of'
godag = GODag(r"C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Entrenamiento\go-basic.obo",
              optional_attrs={'relationship'})
# Out:
# C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Entrenamiento\go-basic.obo: fmt(1.2) rel(2024-01-17) 45,869 Terms; optional_attrs(relationship)

# %%
from goatools.gosubdag.gosubdag import GoSubDag

# Función para obtener los ancestros de un término GO
def obtener_ancestros(GO_ID, godag):
    gosubdag_r0 = GoSubDag([GO_ID], godag)
    return gosubdag_r0.rcntobj.go2ancestors.get(GO_ID, [])

# Diccionario para almacenar genes y sus ancestros GO sin duplicados
nuevo_diccionario = {}

# Recorrer el diccionario ns2assc
for ontologia, genes in ns2assc.items():
    for gen, terminos_go in genes.items():
        if gen in interseccion:
            ancestros = set()
            # Recorrer cada término GO del gen
            for termino_go in terminos_go:
                # Obtener ancestros del término GO
                ancestros.add(termino_go)
                ancestros.update(obtener_ancestros(termino_go, godag))
            # Verificar si el gen ya está en nuevo_diccionario
            if gen in nuevo_diccionario:
                # Extender la lista de ancestros con los nuevos ancestros
                nuevo_diccionario[gen].extend(list(ancestros))
            else:
                # Si el gen no está en nuevo_diccionario, agregarlo con sus ancestros
                nuevo_diccionario[gen] = list(ancestros)
# Out:
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  11 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  10 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
# 1 GO IDs NOT FOUND IN GO DAG: GO:0042788
#  GoSubDag:   0 sources in   0 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  10 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  11 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  10 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  10 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  10 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  13 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  13 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  13 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  13 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
# ...
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  14 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  14 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  11 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  12 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  12 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  10 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  22 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  21 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   9 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  16 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   3 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   2 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   8 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   6 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  17 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in  11 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   7 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   4 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()
#  GoSubDag:   1 sources in   5 GOs rcnt(True). 0 alt GO IDs
#  GoSubDag: namedtuple fields: NS level depth GO alt GO_name dcnt D1 id
#  GoSubDag: relationships: set()

# %%
children_ids = [child.id for child in godag["GO:0008152"].children]
children_ids
# Out:
# ['GO:0042440',
#  'GO:1902421',
#  'GO:1901902',
#  'GO:0009056',
#  'GO:0070988',
#  'GO:0009058',
#  'GO:0042445',
#  'GO:1901286',
#  'GO:0044237',
#  'GO:0018933',
#  'GO:0044238',
#  'GO:0042414',
#  'GO:1990845',
#  'GO:0070085',
#  'GO:0016999',
#  'GO:0032259',
#  'GO:0045730',
#  'GO:0071704',
#  'GO:0051189',
#  'GO:0019748',
#  'GO:0032963',
#  'GO:1901764',
#  'GO:0044281',
#  'GO:0006807',
#  'GO:0140651',
#  'GO:1901275']

# %%
# IDs que deseas excluir
exclude_ids = {"GO:0009058", "GO:0043170", "GO:0044238"}
# Filtrar los términos excluyendo los no deseados
filtered_ids = [go_id for go_id in children_ids if go_id not in exclude_ids]

# %%
dic = {'Mitocondria': ['GO:0005739'],
      'Citoplasma': ['GO:0005737'],
      'Nucleo': ['GO:0005634'],
      'Membrana': ['GO:0016020'],
      'Retículo endoplasmático': ['GO:0005783'],
#       'Metabolismo': ['GO:0019222', 'GO:0019748', 'GO:0009893', 'GO:0009058', 'GO:0044238', 'GO:0044237'],
      'Metabolismo' : ['GO:0008152'],
       #GO:0019222 = regulation of metabolic process
       #GO:0019748 = secondary metabolic process
       #GO:0009893 = positive regulation of metabolic process
       #GO:0009058 = biosynthetic process
       #GO:0044238 = primary metabolic process
       #GO:0044237 = cellular metabolic process
      'Procesos metabólicos\n del RNA': ['GO:0016070'],
      'Traducción': ['GO:0006412','GO:0006417', 'GO:0017148','GO:0045727'],
      'Otro': []}

# %%
dic.values()
# Out:
# dict_values([['GO:0005739'], ['GO:0005737'], ['GO:0005634'], ['GO:0016020'], ['GO:0005783'], ['GO:0008152'], ['GO:0016070'], ['GO:0006412', 'GO:0006417', 'GO:0017148', 'GO:0045727'], []])

# %%
import pandas as pd
# Crear una lista de nombres de genes
# genes = list(nuevo_diccionario.keys())

# Crear un DataFrame lleno de aceros con genes como índice y las claves de dic como columnas
df = pd.DataFrame(0, index=interseccion, columns=dic.keys())

# Llenar el DataFrame con 1 si el término GO está presente para el gen correspondiente
for gen, go_terms in nuevo_diccionarionario.items():
    encontrado = False
    for go_term in go_terms:
        for term_name, lista in dic.items():
            for i in lista: 
                if go_term == i:
#                     col = [key for key, value in dic.items() if value == go_term][0]
                    df.at[gen, term_name] = 1
                    encontrado = True
    if not encontrado:
        df.at[gen, 'Otro'] = 1
                    

df.index = interseccion_names
df = df.sort_index()

# %%
df
# Out:
#           Mitocondria  Citoplasma  Nucleo  Membrana  Retículo endoplasmático  \
# C14B9.10            1           0       0         1                        0
# C25A1.16            0           0       0         0                        0
# C48B6.10            0           0       0         1                        0
# F23H11.5            0           0       0         1                        0
# F29B9.11            0           0       0         1                        0
# ...               ...         ...     ...       ...                      ...
# vha-17              0           0       0         1                        0
# vha-4               0           0       0         1                        0
# vha-8               0           1       0         1                        0
# vha-9               0           0       0         1                        0
# zig-7               0           0       0         1                        0
#
#           Metabolismo  Procesos metabólicos\n del RNA  Traducción  Otro
# C14B9.10            1                               0           0     0
# C25A1.16            0                               0           0     0
# C48B6.10            0                               0           0     0
# F23H11.5            0                               0           0     0
# F29B9.11            0                               0           0     0
# ...               ...                             ...         ...   ...
# vha-17              0                               0           0     0
# vha-4               0                               0           0     0
# vha-8               0                               0           0     0
# vha-9               0                               0           0     0
# zig-7               0                               0           0     0
#
# [103 rows x 9 columns]

# %%
df['Citoplasma'] = df['Citoplasma'].replace(1, 2)
df['Nucleo'] = df['Nucleo'].replace(1, 3)
df['Membrana'] = df['Membrana'].replace(1, 4)
df['Retículo endoplasmático'] = df['Retículo endoplasmático'].replace(1, 5)
df['Metabolismo'] = df['Metabolismo'].replace(1, 6)
df['Procesos metabólicos\n del RNA'] = df['Procesos metabólicos\n del RNA'].replace(1, 7)
df['Traducción'] = df['Traducción'].replace(1, 8)
df['Otro'] = df['Otro'].replace(1, 9)

# %%
df.to_csv('tabla_GOs_tilesplot.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el heatmap
plt.figure(figsize=(10, 30))
sns.heatmap(df, annot=False,cmap="crest")
plt.title("Heatmap de Términos GO por Genes")
plt.xlabel("Términos GO")
plt.ylabel("Genes")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
for namespace, associations in ns2assc.items():
    for protein_id, go_ids in sorted(associations.items()):
        if protein_id == 'WBGene00015514':
            print("{NS} {PROT:7} : {GOs}".format(
                NS=namespace,
                PROT=protein_id,
                GOs=' '.join(sorted(go_ids))))

# %% [markdown]
# # De nuevo

# %%
from goatools.obo_parser import GODag
from goatools.associations import read_gaf
import pandas as pd

# Cargar la estructura GO (archivo .obo)
go_dag = GODag(r"C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Entrenamiento\go-basic.obo",
              optional_attrs={'relationship'})

# Leer las anotaciones GO de los genes (archivo GAF)
gene_annotations = read_gaf(r"C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Analisis_interseccion\wb.gaf", 
                            godag=go_dag,
                            optional_attrs={"evidence", "qualifier"} 
                           )

# Lista de genes que te interesa analizar
genes_of_interest = interseccion # Reemplaza con tus genes específicos
# Out:
# C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Entrenamiento\go-basic.obo: fmt(1.2) rel(2024-01-17) 45,869 Terms; optional_attrs(relationship)
#
# **WARNING: NO VERSION LINE FOUND IN GAF FILE. USING:
# !gaf-version: 2.2
# ERROR:root:Failed to validate header as GAF v2.2:
# []
# HMS:0:00:02.369062 133,336 annotations READ: C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Analisis_interseccion\wb.gaf
# 9882 IDs in loaded association branch, BP

# %%
from collections import defaultdict

# Diccionario para almacenar anotaciones GO
gene_annotations = defaultdict(set)

# Leer el archivo GAF
with open(r"C:\Users\masoz\Desktop\TesisMaestria\Supervisado\Analisis_interseccion\wb.gaf") as gaf_file:
    for line in gaf_file:
        if line.startswith("!"):  # Ignorar comentarios
            continue
        fields = line.strip().split("\t")
        gene_id = fields[1]  # ID del gen
        go_term = fields[4]  # Término GO
        qualifier = fields[3]  # Relación (e.g., enables, involved_in, located_in)
        
        # Incluir todas las relaciones, incluyendo located_in
        if qualifier in {"located_in", "enables", "involved_in"}:
            gene_annotations[gene_id].add(go_term)

# %%
gene_annotations['WBGene00000063']
# Out:
# {'GO:0000166',
#  'GO:0000281',
#  'GO:0005200',
#  'GO:0005524',
#  'GO:0005737',
#  'GO:0005856',
#  'GO:0005865',
#  'GO:0009792',
#  'GO:0030866'}

# %%
# Filtrar las anotaciones GO para solo incluir los genes de interés
# filtered_annotations = {gene: annotations for gene, annotations in gene_annotations.items() if gene in genes_of_interest}
filtered_annotations = {gene: gene_annotations.get(gene, {}) for gene in genes_of_interest}

# Diccionario de términos GO
dic = {
    'Mitocondria': ['GO:0005739'],
    'Citoplasma': ['GO:0005737'],
    'Nucleo': ['GO:0005634'],
    'Membrana': ['GO:0016020'],
    'Retículo endoplasmático': ['GO:0005783'],
    'Metabolismo': ['GO:0008152'],
    'Procesos metabólicos\n del RNA': ['GO:0016070'],
    'Traducción': ['GO:0006412', 'GO:0006417', 'GO:0017148', 'GO:0045727'],
    'Otro': []
}

# Crear un diccionario para almacenar los descendientes de los términos GO
descendants = {category: set() for category in dic}
for category, go_terms in dic.items():
    for term in go_terms:
        if isinstance(term, str) and term in go_dag:
            descendants[category].add(term)
            # Obtener los descendientes del término
            descendants[category].update(go_dag[term].get_all_children())
        elif isinstance(term, set):
            # Si ya es un conjunto (como list_met), simplemente lo asignamos
            descendants[category].update(term)

# Depuración: Imprimir descendientes de cada categoría
for category, go_set in descendants.items():
    print(f"Categoría: {category}, Número de términos GO: {len(go_set)}")

# Remover términos de RNA y Traducción de la categoría Metabolismo
descendants['Metabolismo'] -= (descendants['Procesos metabólicos\n del RNA'] | descendants['Traducción'])

# Depuración: Imprimir el número de términos en Metabolismo después de la exclusión
print(f"Metabolismo filtrado: {len(descendants['Metabolismo'])} términos")

# Crear la tabla
genes = list(filtered_annotations.keys())  # Ahora solo los genes de interés
categories = list(dic.keys())
# Out:
# Categoría: Mitocondria, Número de términos GO: 1
# Categoría: Citoplasma, Número de términos GO: 29
# Categoría: Nucleo, Número de términos GO: 20
# Categoría: Membrana, Número de términos GO: 216
# Categoría: Retículo endoplasmático, Número de términos GO: 6
# Categoría: Metabolismo, Número de términos GO: 5839
# Categoría: Procesos metabólicos
#  del RNA, Número de términos GO: 458
# Categoría: Traducción, Número de términos GO: 127
# Categoría: Otro, Número de términos GO: 0
# Metabolismo filtrado: 5365 términos

# %%
len(filtered_annotations)
# Out:
# 103

# %%
# Inicializar la tabla binaria
table = pd.DataFrame(0, index=genes, columns=categories)

# %%
table
# Out:
#                 Mitocondria  Citoplasma  Nucleo  Membrana  \
# WBGene00012097            0           0       0         0
# WBGene00016655            0           0       0         0
# WBGene00000063            0           0       0         0
# WBGene00011128            0           0       0         0
# WBGene00000182            0           0       0         0
# ...                     ...         ...     ...       ...
# WBGene00021088            0           0       0         0
# WBGene00021248            0           0       0         0
# WBGene00012602            0           0       0         0
# WBGene00022114            0           0       0         0
# WBGene00006984            0           0       0         0
#
#                 Retículo endoplasmático  Metabolismo  \
# WBGene00012097                        0            0
# WBGene00016655                        0            0
# WBGene00000063                        0            0
# WBGene00011128                        0            0
# WBGene00000182                        0            0
# ...                                 ...          ...
# WBGene00021088                        0            0
# WBGene00021248                        0            0
# WBGene00012602                        0            0
# WBGene00022114                        0            0
# WBGene00006984                        0            0
#
#                 Procesos metabólicos\n del RNA  Traducción  Otro
# WBGene00012097                               0           0     0
# WBGene00016655                               0           0     0
# WBGene00000063                               0           0     0
# WBGene00011128                               0           0     0
# WBGene00000182                               0           0     0
# ...                                        ...         ...   ...
# WBGene00021088                               0           0     0
# WBGene00021248                               0           0     0
# WBGene00012602                               0           0     0
# WBGene00022114                               0           0     0
# WBGene00006984                               0           0     0
#
# [103 rows x 9 columns]

# %%
filtered_annotations['WBGene00000063']
# Out:
# {'GO:0000166',
#  'GO:0000281',
#  'GO:0005200',
#  'GO:0005524',
#  'GO:0005737',
#  'GO:0005856',
#  'GO:0005865',
#  'GO:0009792',
#  'GO:0030866'}

# %%
# Rellenar la tabla
for gene, annotations in filtered_annotations.items():
    print('--------------GEN-------------', gene)
    # Anotaciones ya son un conjunto de términos GO
    for GO in annotations: 
        encontrado = False
        i = 1
        for category, go_set in descendants.items():
            if GO in go_set:
                table.loc[gene, category] = i
                encontrado = True
#                 break
            else:
#                 print(GO, category, 'NO ACA')
                pass
            i +=1
        if not encontrado:
            print(GO, 'No está')
            i -= 1
            table.loc[gene, 'Otro'] = i
        
                
#         if gene_gos & go_set:  # Intersección no vacía
#             table.loc[gene, category] = 1
# Out:
# --------------GEN------------- WBGene00012097
# GO:0005524 No está
# GO:0000166 No está
# --------------GEN------------- WBGene00016655
# GO:0000062 No está
# GO:0036042 No está
# GO:0019915 No está
# GO:0008289 No está
# GO:0008340 No está
# --------------GEN------------- WBGene00000063
# GO:0005200 No está
# GO:0000166 No está
# GO:0009792 No está
# GO:0000281 No está
# GO:0005856 No está
# GO:0005524 No está
# GO:0005865 No está
# GO:0030866 No está
# --------------GEN------------- WBGene00011128
# GO:0016740 No está
# GO:0016301 No está
# GO:0000166 No está
# GO:0005515 No está
# GO:0005524 No está
# GO:0004001 No está
# --------------GEN------------- WBGene00000182
# GO:0003924 No está
# GO:0006886 No está
# GO:0007005 No está
# GO:0048599 No está
# GO:1904748 No está
# GO:0000166 No está
# GO:0009792 No está
# GO:0005794 No está
# GO:0005525 No está
# GO:0007276 No está
# GO:0048259 No está
# GO:0016192 No está
# GO:0015031 No está
# --------------GEN------------- WBGene00000183
# GO:0006811 No está
# GO:0009792 No está
# GO:0015078 No está
# GO:0046961 No está
# GO:0007042 No está
# --------------GEN------------- WBGene00006919
# GO:1902600 No está
# GO:0043068 No está
# GO:0006811 No está
# GO:0012501 No está
# GO:0015078 No está
# GO:0046961 No está
# --------------GEN------------- WBGene00020507
# GO:1902600 No está
# GO:0046961 No está
# GO:0006811 No está
# --------------GEN------------- WBGene00009882
# GO:0060142 No está
# GO:1902600 No está
# GO:0010172 No está
# GO:0006811 No está
# GO:0009792 No está
# GO:0055085 No está
# GO:0043296 No está
# GO:0046961 No está
# --------------GEN------------- WBGene00006913
# GO:1902600 No está
# GO:0006811 No está
# GO:0009792 No está
# GO:0015078 No está
# --------------GEN------------- WBGene00006917
# GO:1902600 No está
# GO:0006811 No está
# GO:0046961 No está
# --------------GEN------------- WBGene00006918
# GO:1902600 No está
# GO:0034220 No está
# GO:0006811 No está
# GO:0046961 No está
# GO:0007042 No está
# --------------GEN------------- WBGene00012179
# GO:0003735 No está
# GO:0005840 No está
# GO:0019843 No está
# GO:0003723 No está
# GO:0046872 No está
# --------------GEN------------- WBGene00021088
# --------------GEN------------- WBGene00021248
# GO:0006457 No está
# GO:0140662 No está
# GO:0051082 No está
# GO:0051087 No está
# GO:0005524 No está
# GO:0051085 No está
# GO:0046872 No está
# --------------GEN------------- WBGene00012602
# --------------GEN------------- WBGene00022114
# --------------GEN------------- WBGene00006984
# GO:0005576 No está
# GO:0007411 No está
# GO:0007155 No está

# %%
# go_dag['GO:0008152'].get_all_children()

# %%
table
# Out:
#                 Mitocondria  Citoplasma  Nucleo  Membrana  \
# WBGene00012097            0           0       0         0
# WBGene00016655            0           0       0         0
# WBGene00000063            0           2       0         0
# WBGene00011128            0           0       3         0
# WBGene00000182            0           0       0         0
# ...                     ...         ...     ...       ...
# WBGene00021088            0           0       0         0
# WBGene00021248            0           0       0         0
# WBGene00012602            0           0       0         0
# WBGene00022114            0           2       0         0
# WBGene00006984            0           0       0         4
#
#                 Retículo endoplasmático  Metabolismo  \
# WBGene00012097                        0            0
# WBGene00016655                        0            6
# WBGene00000063                        0            0
# WBGene00011128                        0            6
# WBGene00000182                        5            0
# ...                                 ...          ...
# WBGene00021088                        0            0
# WBGene00021248                        0            0
# WBGene00012602                        0            0
# WBGene00022114                        0            0
# WBGene00006984                        0            0
#
#                 Procesos metabólicos\n del RNA  Traducción  Otro
# WBGene00012097                               0           0     9
# WBGene00016655                               0           0     9
# WBGene00000063                               0           0     9
# WBGene00011128                               0           0     9
# WBGene00000182                               0           0     9
# ...                                        ...         ...   ...
# WBGene00021088                               0           0     0
# WBGene00021248                               0           0     9
# WBGene00012602                               0           0     0
# WBGene00022114                               0           0     0
# WBGene00006984                               0           0     9
#
# [103 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el heatmap
plt.figure(figsize=(10, 30))
sns.heatmap(table, annot=False,cmap="crest")
plt.title("Heatmap de Términos GO por Genes")
plt.xlabel("Términos GO")
plt.ylabel("Genes")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
table.to_csv('tabla_GOs_tilesplot2.csv')
